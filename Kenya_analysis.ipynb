# %%
import warnings

import self as self

warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True)
plt.rc("axes", labelweight="bold", labelsize="large", titleweight="bold", titlesize=14, titlepad=10)
df = pd.read_csv(r'C:\Users\user\PycharmProjects\hit_music\Naija100.csv')


def num_plot(df2, col):
    fig, ax = plt.subplots(2, 1, sharex=True, figsize=(8,5),gridspec_kw={"height_ratios": (.2, .8)})
    ax[0].set_title(col + 'distribution',fontsize=18)
    sns.boxplot(x=col, data=df2, ax=ax[0])
    ax[0].set(yticks=[])
    sns.histplot(x=col, data=df2, ax=ax[1])
    ax[1].set_xlabel(col, fontsize=16)
    plt.tight_layout()
    plt.show()

def plot_features_obj(df,string):
    fig, ax = plt.subplots(2,4, figsize=(18,9), sharey=True)
    fig.suptitle('TOP 100 songs musical attributes by Release Year', fontsize=40)
    g=sns.barplot(ax=ax[0,0], x=string, y= 'energy', data=df,ci=False, palette='rocket')
    g.bar_label(g.containers[0], fmt='%.1f', fontsize=10)
    ax[0,0].set_title('energy')
    ax[0,0].set_xlabel('')
    ax[0,0].set_ylabel('')
    ax[0,0].tick_params(axis='y',labelsize=17)

    g=sns.barplot(ax=ax[0,1], x=string, y= 'danceability', data=df,ci=False, palette='crest_r')
    g.bar_label(g.containers[0], fmt='%.1f', fontsize=10)
    ax[0,1].set_title('danceability')
    ax[0,1].set_ylabel('')
    ax[0,1].set_xlabel('')

    g=sns.barplot(ax=ax[0,2], x=string, y= 'liveness', data=df,ci=False, palette='magma')
    g.bar_label(g.containers[0], fmt='%.1f', fontsize=10)
    g.bar_label(g.containers[0], fmt='%.1f', fontsize=10)
    ax[0,2].set_title('liveness')
    ax[0,2].set_ylabel('')
    ax[0,2].set_xlabel('')

    g=sns.barplot(ax=ax[0,3], x=string, y= 'valence', data=df,ci=False, palette='flare_r')
    g.bar_label(g.containers[0], fmt='%.1f', fontsize=10)
    ax[0,3].set_title('valence')
    ax[0,3].set_ylabel('')
    ax[0,3].set_xlabel('')

    # g=sns.barplot(ax=ax[1,0], x=string, y= 'acousticness', data=df,ci=False, palette='mako')
    # g.bar_label(g.containers[0], fmt='%.1f', fontsize=10)
    # ax[1,0].set_title('acousticness')
    # ax[1,0].set_ylabel('')
    # ax[1,0].set_xlabel('')
    # ax[1,0].tick_params(axis='y',labelsize=17)

    g=sns.barplot(ax=ax[1,1], x=string, y= 'speechiness', data=df,ci=False, palette='cubehelix')
    g.bar_label(g.containers[0], fmt='%.1f', fontsize=10)
    ax[1,1].set_title('speechiness')
    ax[1,1].set_ylabel('')
    ax[1,1].set_xlabel('')


    # g=sns.barplot(ax=ax[1,2], x=string, y= 'popularity', data=df,ci=False, palette='YlOrBr_r')
    # g.bar_label(g.containers[0], fmt='%.1f', fontsize=10)
    # ax[1,2].set_title('popularity')
    # ax[1,2].set_ylabel('')
    # ax[1,2].set_xlabel('')
    # ax=ax[1,3].axis('off')
    # plt.tight_layout()
    plt.show()

# def plot_features(df, text, ax):
#         ax.set_title('Musical Attributes densities of songs by ' + text)
#         sns.kdeplot(x= 'energy', data=df, label='energy',ax=ax)
#         sns.kdeplot(x= 'danceability', data=df, label='danceability',ax=ax)
#         sns.kdeplot(x= 'liveness', data=df, label='liveness',ax=ax)
#         sns.kdeplot(x= 'tempo', data=df, label='tempo',ax=ax)
#         sns.kdeplot(x= 'valance', data=df, label='valance',ax=ax)
#         # sns.kdeplot(x= 'acousticness', data=df, label='acousticness',ax=ax)
#         sns.kdeplot(x= 'speechiness', data=df, label='speechiness',ax=ax)
#         ax.set_xlabel('')
#         ax.legend(fontsize=10, fancybox=True, shadow=True, frameon=True)
#
#         plt.legend()

# %%
df = pd.read_csv(r'C:\Users\user\PycharmProjects\hit_music\Kenya100.csv')
df.describe()
# Out:
#        danceability     energy        key   loudness       mode  speechiness  \
# count      60.00000  60.000000  60.000000  60.000000  60.000000    60.000000
# mean        0.73110   0.644417   5.266667  -6.818967   0.533333     0.157985
# std         0.14187   0.129825   3.830593   2.160905   0.503098     0.105370
# min         0.39200   0.354000   0.000000 -16.408000   0.000000     0.036400
# 25%         0.64525   0.551750   1.000000  -7.617750   0.000000     0.068750
# 50%         0.74600   0.659000   6.000000  -6.758500   1.000000     0.120500
# 75%         0.82025   0.718250   8.250000  -5.498000   1.000000     0.234250
# max         0.96600   0.929000  11.000000  -2.653000   1.000000     0.423000
#
#        instrumentalness   liveness    valence       tempo    duration_ms  \
# count         60.000000  60.000000  60.000000   60.000000      60.000000
# mean           0.009608   0.151367   0.572050  113.312433  199312.200000
# std            0.052717   0.079222   0.215614   27.689776   58856.255393
# min            0.000000   0.048200   0.136000   74.085000   97393.000000
# 25%            0.000000   0.099625   0.374250   97.815250  167212.000000
# 50%            0.000008   0.115500   0.611500  104.495000  188423.000000
# 75%            0.000207   0.200000   0.723250  117.002000  214742.000000
# max            0.402000   0.403000   0.972000  196.280000  501648.000000
#
#        time_signature
# count       60.000000
# mean         3.916667
# std          0.561223
# min          1.000000
# 25%          4.000000
# 50%          4.000000
# 75%          4.000000
# max          5.000000

# %%
kenya_Leading = df.head()
kenya_leading2 =df.iloc[:20]
plt.figure(figsize=(20,8))
g=sns.barplot(x='artist', y= 'duration_ms', data=kenya_leading2, ci=False, palette='viridis')
g.bar_label(g.containers[0], fmt='%.1f', fontsize=14)
plt.ylabel('Duration(ms)', fontsize=14)
plt.xticks(fontsize=10)
plt.xlabel('Song', fontsize=11)
plt.title('Song vs Duration(ms)', fontsize=20)
plt.show()

# %%
# kenya_leading3 =df.iloc[:17]
plt.figure(figsize=(14,5))
g=sns.barplot(x='artist', y= 'loudness', data=kenya_leading2, ci=False, palette='Reds_r')
g.bar_label(g.containers[0], fmt='%.1f', fontsize=14)
plt.ylabel('loudness', fontsize=10)
plt.xticks(fontsize=9)
plt.xlabel('Artist', fontsize=10)
plt.title('Loudness vs Artist', fontsize=20)
plt.show()

# %%
df_feat = df.drop(['album','artist','track_id','loudness','duration_ms','time_signature','tempo','key','instrumentalness'], axis=1)
df_mean = pd.DataFrame(df_feat.mean().sort_values(ascending=False).reset_index())
df_mean.rename(columns={ df_mean.columns[1]: "value" }, inplace = True)
plt.figure(figsize=(8,5))
plt.title('Musical attributes mean values', fontsize=25)
g = sns.barplot(x='index', y='value', data=df_mean, palette='Reds_r')
g.bar_label(g.containers[0], fmt='%.1f', fontsize=16)
plt.xlabel('')
plt.xticks(fontsize=12)
plt.ylabel('Value', fontsize=18)
plt.yticks(fontsize=15)
plt.show()

# %%
song_No = df['artist'].value_counts()
print(song_No)
# Out:
# Burna Boy              3
# Ayra Starr             2
# Uncojingjong           2
# Ruger                  2
# Fireboy DML            2
# Rema                   2
# Beyoncé                2
# Chris Brown            2
# Asake                  2
# BURUKLYN BOYZ          2
# Zuchu                  1
# Brent Faiyaz           1
# Khaligraph Jones       1
# Giveon                 1
# Otile Brown            1
# FEMI ONE               1
# Brandy Maina           1
# Pheelz                 1
# Marioo                 1
# Drake                  1
# CKay                   1
# Lexsil                 1
# Koffee                 1
# Future                 1
# Jack Harlow            1
# Chris Kaiga            1
# Post Malone            1
# Nicki Minaj            1
# Lilmaina               1
# Kizz Daniel            1
# Lojay                  1
# Oxlade                 1
# Mavins                 1
# Jay Melody             1
# K.O                    1
# AKA                    1
# Sam Smith              1
# Fully Focus            1
# Ice Spice              1
# DJ Khaled              1
# Victony                1
# Gidi Gidi Maji Maji    1
# Wakadinali             1
# Camidoh                1
# Limoblaze              1
# Central Cee            1
# Bien                   1
# Fave                   1
# Black Sherif           1
# Name: artist, dtype: int64

# %%
df['artist'].nunique()
# Out:
# 49

# %%
plt.figure(figsize=(8,5.5))
plt.title('No. of distinct songs in TOP100 by distinct artist ', fontsize=18)
g = sns.countplot(df['artist'].value_counts(ascending=True).values)
g.bar_label(g.containers[0], fmt='%.0f', fontsize=16)
plt.ylabel('No. artists', fontsize=20)
plt.xticks(fontsize=12)
plt.xlabel('No. songs ', fontsize=18)
plt.yticks(fontsize=15)
plt.show()

# %%
df_art = df['artist'].value_counts()

# %%
top_art = df_art[df_art > 1]
top_art
# Out:
# Burna Boy        3
# Ayra Starr       2
# Uncojingjong     2
# Ruger            2
# Fireboy DML      2
# Rema             2
# Beyoncé          2
# Chris Brown      2
# Asake            2
# BURUKLYN BOYZ    2
# Name: artist, dtype: int64

# %%
# plt.figure(figsize=(10,6))
# plt.title('No. different songs in TOP100 by artist')
# g=sns.barplot(top_art.index, top_art, palette='mako')
# g.bar_label(g.containers[0], fmt='%.0f', fontsize=16)
# plt.xticks(rotation=90)
# plt.yticks([])
# plt.ylabel('No.Songs')
# plt.show()
plt.figure(figsize=(8,5.5))
plt.title('No. of distinct songs in TOP 20  by distinct artist ', fontsize=18)
plt.ylabel('No. Songs', fontsize=20)
plt.xticks(fontsize=12)
plt.xlabel('Artist ', fontsize=18)
plt.xticks(fontsize=12)
df['artist'].value_counts()[:20].plot(kind='bar')
# Out:
# <AxesSubplot:title={'center':'No. of distinct songs in TOP 20  by distinct artist '}, xlabel='Artist ', ylabel='No. Songs'>

# %%
plt.figure(figsize=(18,7))
current_palette = sns.color_palette("BuGn_r", 10)
g=sns.barplot(x='artist', y= 'tempo', data=kenya_leading2, ci=False, palette=current_palette)
g.bar_label(g.containers[0], fmt='%.1f', fontsize=14)
plt.ylabel('tempo', fontsize=10)
plt.xticks(fontsize=12)
plt.xlabel('Artist', fontsize=10)
plt.title('Tempo vs Artist (Top 20)', fontsize=20)
plt.show()

# %%
def plot_features(df, text, ax):
        ax.set_title('Musical Attributes densities of songs by ' + text)
        sns.kdeplot(x= 'energy', data=df, label='energy',ax=ax)
        sns.kdeplot(x= 'danceability', data=df, label='danceability',ax=ax)
        sns.kdeplot(x= 'liveness', data=df, label='liveness',ax=ax)
        # sns.kdeplot(x= 'tempo', data=df, label='tempo',ax=ax)
        # sns.kdeplot(x= 'acousticness', data=df, label='acousticness',ax=ax)
        sns.kdeplot(x= 'speechiness', data=df, label='speechiness',ax=ax)
        # sns.kdeplot(x= 'valance', data=df, label='valance',ax=ax)
        # sns.kdeplot(x= 'instrumentalness', data=df, label='instrumentalness',ax=ax)
        ax.set_xlabel('')
        ax.legend(fontsize=10, fancybox=True, shadow=True, frameon=True)

        # plt.legend()
_, ax = plt.subplots(2,2, figsize=(16,7))

plot_features(df,'all artists',ax[0,0])
plot_features(df[df['artist']== 'Ayra Starr'],'Ayra Starr',ax[0,1])
plot_features(df[df['artist']== 'BURUKLYN BOYZ'],'BURUKLYN BOYZ',ax[1,0])
plot_features(df[df['artist']== 'Burna Boy'],'Burna Boy',ax[1,1])
# plot_features(df[df['artist']== 'Ruger'],'Ruger',ax[1,1])
# plot_features(df[df['artist']== 'Fireboy DML'],'Fireboy DML',ax[1,1])
#
plt.show()
